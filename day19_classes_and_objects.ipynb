# %%
from IPython.core.magic import register_cell_magic

@register_cell_magic
def add_method_to(line, cell):
    cls = eval(line.strip())
    namespace = {}
    exec(cell, globals(), namespace)
    for name, obj in namespace.items():
        setattr(cls, name, obj)

# %%
class Point:
    """Represents a point in 2-d space."""

    def __init__(self, x, y):
        self.x = x
        self.y = y

    def __str__(self):
        return f"Point({self.x}, {self.y})"

# %%
start = Point(0, 0)
print(start)
# Out:
# Point(0, 0)

# %%
# %%add_method_to Point
#
# def translate(self, dx, dy):
#     self.x += dx
#     self.y += dy

# %%
from copy import copy

end1 = copy(start)
end1.translate(300, 0)
print(end1)
# Out:
# Point(300, 0)

# %%
# %%add_method_to Point
#
# def translated(self, dx=0, dy=0):
#     point = copy(self)
#     point.translate(dx, dy)
#     return point

# %%
end2 = start.translated(0, 150)
print(end2)
# Out:
# Point(0, 150)

# %%
class Line:
    """Represents a line."""

    def __init__(self, p1, p2):
        self.p1 = p1
        self.p2 = p2

    def __str__(self):
        return f"Line({self.p1}, {self.p2})"

# %%
line1 = Line(start, end1)
print(line1)
# Out:
# Line(Point(0, 0), Point(300, 0))

# %%
from jupyturtle import make_turtle, jumpto, moveto

# %%
# %%add_method_to Line
#
# def draw(self):
#     jumpto(self.p1.x, self.p1.y)
#     moveto(self.p2.x, self.p2.y)

# %%
line2 = Line(start, end2)
print(line2)
# Out:
# Line(Point(0, 0), Point(0, 150))

# %%
make_turtle()
line1.draw()
line2.draw()
# Out:
# <svg width="300" height="150" style="fill:none; stroke-linecap:round;">
#     <rect width="100%" height="100%" fill="#F3F3F7" />
#
#
# <path stroke="#663399" stroke-width="2" d="M 150,75" />'
#
# <path stroke="#663399" stroke-width="2" d="M 0,0 300,0" />'
#
# <path stroke="#663399" stroke-width="2" d="M 0,0 0,150" />'
#
# <g transform="rotate(-90.0,0,150) translate(0, 150)">
#     <circle stroke="#63A375" stroke-width="2" fill="transparent" r="5.5" cx="0" cy="0"/>
#     <polygon points="0,12 2,9 -2,9" style="fill:#63A375;stroke:#63A375;stroke-width:2"/>
# </g>
#
# </svg>

# %%
p1 = Point(200, 100)
p2 = Point(200, 100)

# %%
p1 == p2
# Out:
# False

# %%
# %%add_method_to Point
#
# def __eq__(self, other):
#     return (self.x  == other.x) and (self.y == other.y)

# %%
p1 == p2
# Out:
# True

# %%
p1 is p2
# Out:
# False

# %%
class Rectangle:
    """Represents a rectangle.
    
    attributes: width, heigth, corner.
    """
    def __init__(self, width, heigth, corner):
        self.width = width
        self.heigth = heigth
        self.corner = corner
    
    def __str__(self):
        return f'Rectange({self.width}, {self.heigth}, {self.corner})'

# %%
corner = Point(30, 20)
box1 = Rectangle(100, 50, corner)
print(box1)
# Out:
# Rectange(100, 50, Point(30, 20))

# %%
# %%add_method_to Rectangle
#
# def make_points(self):
#     p1 = self.corner
#     p2 = p1.translated(self.width, 0)
#     p3 = p2.translated(0, self.heigth)
#     p4 = p3.translated(-self.width, 0)
#     return p1, p2, p3, p4

# %%
# %%add_method_to Rectangle
#
# def make_lines(self):
#     p1, p2, p3, p4 = self.make_points()
#     return Line(p1, p2), Line(p2, p3), Line(p3, p4), Line(p4, p1)

# %%
# %%add_method_to Rectangle
#
# def draw(self):
#     lines = self.make_lines()
#     for line in lines:
#         line.draw()

# %%
make_turtle()
line1.draw()
line2.draw()
box1.draw()
# Out:
# <svg width="300" height="150" style="fill:none; stroke-linecap:round;">
#     <rect width="100%" height="100%" fill="#F3F3F7" />
#
#
# <path stroke="#663399" stroke-width="2" d="M 150,75" />'
#
# <path stroke="#663399" stroke-width="2" d="M 0,0 300,0" />'
#
# <path stroke="#663399" stroke-width="2" d="M 0,0 0,150" />'
#
# <path stroke="#663399" stroke-width="2" d="M 30,20 130,20" />'
#
# <path stroke="#663399" stroke-width="2" d="M 130,20 130,70" />'
#
# <path stroke="#663399" stroke-width="2" d="M 130,70 30,70" />'
#
# <path stroke="#663399" stroke-width="2" d="M 30,70 30,20" />'
#
# <g transform="rotate(-90.0,30,20) translate(30, 20)">
#     <circle stroke="#63A375" stroke-width="2" fill="transparent" r="5.5" cx="0" cy="0"/>
#     <polygon points="0,12 2,9 -2,9" style="fill:#63A375;stroke:#63A375;stroke-width:2"/>
# </g>
#
# </svg>

# %%
# %%add_method_to Rectangle
#
# def grow(self, dwidth, dheigth):
#     self.width += dwidth
#     self.heigth += dheigth

# %%
box2 = copy(box1)
box1.grow(60, 40)
print(box2)
# Out:
# Rectange(100, 50, Point(30, 20))

# %%
make_turtle()
line1.draw()
line2.draw()
box1.draw()
box2.draw()
# Out:
# <svg width="300" height="150" style="fill:none; stroke-linecap:round;">
#     <rect width="100%" height="100%" fill="#F3F3F7" />
#
#
# <path stroke="#663399" stroke-width="2" d="M 150,75" />'
#
# <path stroke="#663399" stroke-width="2" d="M 0,0 300,0" />'
#
# <path stroke="#663399" stroke-width="2" d="M 0,0 0,150" />'
#
# <path stroke="#663399" stroke-width="2" d="M 30,20 190,20" />'
#
# <path stroke="#663399" stroke-width="2" d="M 190,20 190,110" />'
#
# <path stroke="#663399" stroke-width="2" d="M 190,110 30,110" />'
#
# <path stroke="#663399" stroke-width="2" d="M 30,110 30,20" />'
#
# <path stroke="#663399" stroke-width="2" d="M 30,20 130,20" />'
#
# <path stroke="#663399" stroke-width="2" d="M 130,20 130,70" />'
#
# <path stroke="#663399" stroke-width="2" d="M 130,70 30,70" />'
#
# <path stroke="#663399" stroke-width="2" d="M 30,70 30,20" />'
#
# <g transform="rotate(-90.0,30,20) translate(30, 20)">
#     <circle stroke="#63A375" stroke-width="2" fill="transparent" r="5.5" cx="0" cy="0"/>
#     <polygon points="0,12 2,9 -2,9" style="fill:#63A375;stroke:#63A375;stroke-width:2"/>
# </g>
#
# </svg>

# %%
# %%add_method_to Rectangle
#
# def translate(self, dx, dy):
#     self.corner.translate(dx, dy)

# %%
box2.translate(30, 20)
print(box2)
# Out:
# Rectange(100, 50, Point(60, 40))

# %%
make_turtle()
line1.draw()
line2.draw()
box1.draw()
box2.draw()
# Out:
# <svg width="300" height="150" style="fill:none; stroke-linecap:round;">
#     <rect width="100%" height="100%" fill="#F3F3F7" />
#
#
# <path stroke="#663399" stroke-width="2" d="M 150,75" />'
#
# <path stroke="#663399" stroke-width="2" d="M 0,0 300,0" />'
#
# <path stroke="#663399" stroke-width="2" d="M 0,0 0,150" />'
#
# <path stroke="#663399" stroke-width="2" d="M 60,40 220,40" />'
#
# <path stroke="#663399" stroke-width="2" d="M 220,40 220,130" />'
#
# <path stroke="#663399" stroke-width="2" d="M 220,130 60,130" />'
#
# <path stroke="#663399" stroke-width="2" d="M 60,130 60,40" />'
#
# <path stroke="#663399" stroke-width="2" d="M 60,40 160,40" />'
#
# <path stroke="#663399" stroke-width="2" d="M 160,40 160,90" />'
#
# <path stroke="#663399" stroke-width="2" d="M 160,90 60,90" />'
#
# <path stroke="#663399" stroke-width="2" d="M 60,90 60,40" />'
#
# <g transform="rotate(-90.0,60,40) translate(60, 40)">
#     <circle stroke="#63A375" stroke-width="2" fill="transparent" r="5.5" cx="0" cy="0"/>
#     <polygon points="0,12 2,9 -2,9" style="fill:#63A375;stroke:#63A375;stroke-width:2"/>
# </g>
#
# </svg>

# %%
box1 is box2
# Out:
# False

# %%
box1.corner is box2.corner
# Out:
# True

# %%
corner = Point(20, 20)
box3 = Rectangle(100, 50, corner)
print(box3)
# Out:
# Rectange(100, 50, Point(20, 20))

# %%
from copy import deepcopy

box4 = deepcopy(box3)

# %%
box3.corner is box4.corner
# Out:
# False

# %%
box3.translate(50, 30)
box4.grow(100, 50)

# %%
make_turtle()
line1.draw()
line2.draw()
box3.draw()
box4.draw()
# Out:
# <svg width="300" height="150" style="fill:none; stroke-linecap:round;">
#     <rect width="100%" height="100%" fill="#F3F3F7" />
#
#
# <path stroke="#663399" stroke-width="2" d="M 150,75" />'
#
# <path stroke="#663399" stroke-width="2" d="M 0,0 300,0" />'
#
# <path stroke="#663399" stroke-width="2" d="M 0,0 0,150" />'
#
# <path stroke="#663399" stroke-width="2" d="M 70,50 170,50" />'
#
# <path stroke="#663399" stroke-width="2" d="M 170,50 170,100" />'
#
# <path stroke="#663399" stroke-width="2" d="M 170,100 70,100" />'
#
# <path stroke="#663399" stroke-width="2" d="M 70,100 70,50" />'
#
# <path stroke="#663399" stroke-width="2" d="M 20,20 220,20" />'
#
# <path stroke="#663399" stroke-width="2" d="M 220,20 220,120" />'
#
# <path stroke="#663399" stroke-width="2" d="M 220,120 20,120" />'
#
# <path stroke="#663399" stroke-width="2" d="M 20,120 20,20" />'
#
# <g transform="rotate(-90.0,20,20) translate(20, 20)">
#     <circle stroke="#63A375" stroke-width="2" fill="transparent" r="5.5" cx="0" cy="0"/>
#     <polygon points="0,12 2,9 -2,9" style="fill:#63A375;stroke:#63A375;stroke-width:2"/>
# </g>
#
# </svg>

# %%
shapes = [line1, line2, box3, box4]

# %%
make_turtle()

for shape in shapes:
    shape.draw()
# Out:
# <svg width="300" height="150" style="fill:none; stroke-linecap:round;">
#     <rect width="100%" height="100%" fill="#F3F3F7" />
#
#
# <path stroke="#663399" stroke-width="2" d="M 150,75" />'
#
# <path stroke="#663399" stroke-width="2" d="M 0,0 300,0" />'
#
# <path stroke="#663399" stroke-width="2" d="M 0,0 0,150" />'
#
# <path stroke="#663399" stroke-width="2" d="M 70,50 170,50" />'
#
# <path stroke="#663399" stroke-width="2" d="M 170,50 170,100" />'
#
# <path stroke="#663399" stroke-width="2" d="M 170,100 70,100" />'
#
# <path stroke="#663399" stroke-width="2" d="M 70,100 70,50" />'
#
# <path stroke="#663399" stroke-width="2" d="M 20,20 220,20" />'
#
# <path stroke="#663399" stroke-width="2" d="M 220,20 220,120" />'
#
# <path stroke="#663399" stroke-width="2" d="M 220,120 20,120" />'
#
# <path stroke="#663399" stroke-width="2" d="M 20,120 20,20" />'
#
# <g transform="rotate(-90.0,20,20) translate(20, 20)">
#     <circle stroke="#63A375" stroke-width="2" fill="transparent" r="5.5" cx="0" cy="0"/>
#     <polygon points="0,12 2,9 -2,9" style="fill:#63A375;stroke:#63A375;stroke-width:2"/>
# </g>
#
# </svg>

# %%
# Practice

# %%
class Point_1:
    """Represent a point in a 2d space."""

    def __init__(self, x, y):
        self.x = x
        self.y = y

    def __str__(self):
        return f'Point1({self.x}, {self.y})'

# %%
p1 = Point_1(0, 0)

# %%
print(p1)
# Out:
# Point1(0, 0)

# %%
# %%add_method_to Point_1
#
# def translate(self, dx, dy):
#     self.x += dx
#     self.y += dy

# %%
p2 = copy(p1)
p2.translate(300, 0)
print(p2)
# Out:
# Point1(300, 0)

# %%
# %%add_method_to Point_1
#
# def translated(self, dx=0, dy=0):
#     point = copy(self)
#     point.translate(dx, dy)
#     return point

# %%
p3 = p1.translated(0, 150)
print(p3)
# Out:
# Point1(0, 150)

# %%
class Line1:
    """Represent a line."""

    def __init__(self, p1, p2):
        self.p1 = p1
        self.p2 = p2
    
    def __str__(self):
        return f'Line({self.p1}, {self.p2})'

# %%
line1 = Line1(p1, p2)
print(line1)
# Out:
# Line(Point1(0, 0), Point1(300, 0))

# %%
# %%add_method_to Line1
#
# def draw(self):
#     jumpto(self.p1.x, self.p1.y)
#     moveto(self.p2.x, self.p2.y)

# %%
line2 = Line1(p1, p3)
print(line2)
# Out:
# Line(Point1(0, 0), Point1(0, 150))

# %%
make_turtle()
line1.draw()
line2.draw()
# Out:
# <svg width="300" height="150" style="fill:none; stroke-linecap:round;">
#     <rect width="100%" height="100%" fill="#F3F3F7" />
#
#
# <path stroke="#663399" stroke-width="2" d="M 150,75" />'
#
# <path stroke="#663399" stroke-width="2" d="M 0,0 300,0" />'
#
# <path stroke="#663399" stroke-width="2" d="M 0,0 0,150" />'
#
# <g transform="rotate(-90.0,0,150) translate(0, 150)">
#     <circle stroke="#63A375" stroke-width="2" fill="transparent" r="5.5" cx="0" cy="0"/>
#     <polygon points="0,12 2,9 -2,9" style="fill:#63A375;stroke:#63A375;stroke-width:2"/>
# </g>
#
# </svg>

# %%
p4 = Point_1(200, 100)
p5 = Point_1(200, 100)

# %%
p4 == p5
# Out:
# False

# %%
p4 is p5
# Out:
# False

# %%
# %%add_method_to Point_1
#
# def __eq__(self, other):
#     return (self.x == other.x) and (self.y == other.y)

# %%
p4 == p5
# Out:
# True

# %%
p4 is p5
# Out:
# False

# %%
class Rectangle_1:
    """Represents a rectangle.
    
    attribute: width, heigth, corner
    """
    def __init__(self, width, heigth, corner):
        self.width = width
        self.heigth = heigth
        self.corner = corner

    def __str__(self):
        return f'Rectangle({self.width}, {self.heigth}, {self.corner})'

# %%
corner = Point(30, 20)
box1 = Rectangle(100, 50, corner)
print(box1)
# Out:
# Rectange(100, 50, Point(30, 20))

# %%
# %%add_method_to Rectangle_1
#
# def make_points(self):
#     p1 = self.corner
#     p2 = p1.translated(self.width, 0)
#     p3 = p2.translated(0, self.heigth)
#     p4 = p3.translated(-self.width, 0)
#     return p1, p2, p3, p4

# %%
# %%add_method_to Rectangle_1
#
# def make_lines(self):
#     p1, p2, p3, p4 = self.make_points()
#     return Line(p1, p2), Line(p2, p3), Line(p3, p4), Line(p4,p1)

# %%
# %%add_method_to Rectangle_1
#
# def draw(self):
#     lines = self.make_lines()
#     for line in lines:
#         line.draw()

# %%
make_turtle()
line1.draw()
line2.draw()
box1.draw()
# Out:
# <svg width="300" height="150" style="fill:none; stroke-linecap:round;">
#     <rect width="100%" height="100%" fill="#F3F3F7" />
#
#
# <path stroke="#663399" stroke-width="2" d="M 150,75" />'
#
# <path stroke="#663399" stroke-width="2" d="M 0,0 300,0" />'
#
# <path stroke="#663399" stroke-width="2" d="M 0,0 0,150" />'
#
# <path stroke="#663399" stroke-width="2" d="M 30,20 130,20" />'
#
# <path stroke="#663399" stroke-width="2" d="M 130,20 130,70" />'
#
# <path stroke="#663399" stroke-width="2" d="M 130,70 30,70" />'
#
# <path stroke="#663399" stroke-width="2" d="M 30,70 30,20" />'
#
# <g transform="rotate(-90.0,30,20) translate(30, 20)">
#     <circle stroke="#63A375" stroke-width="2" fill="transparent" r="5.5" cx="0" cy="0"/>
#     <polygon points="0,12 2,9 -2,9" style="fill:#63A375;stroke:#63A375;stroke-width:2"/>
# </g>
#
# </svg>

# %%
# %%add_method_to Rectangle_1
#
# def grow(self, dwidth, dheigth):
#     self.width += dwidth
#     self.heigth += dheigth

# %%
box2 = copy(box1)
box2.grow(60, 40)
print(box2)
# Out:
# Rectange(160, 90, Point(30, 20))

# %%
make_turtle()
line1.draw()
line2.draw()
box1.draw()
box2.draw()
# Out:
# <svg width="300" height="150" style="fill:none; stroke-linecap:round;">
#     <rect width="100%" height="100%" fill="#F3F3F7" />
#
#
# <path stroke="#663399" stroke-width="2" d="M 150,75" />'
#
# <path stroke="#663399" stroke-width="2" d="M 0,0 300,0" />'
#
# <path stroke="#663399" stroke-width="2" d="M 0,0 0,150" />'
#
# <path stroke="#663399" stroke-width="2" d="M 30,20 130,20" />'
#
# <path stroke="#663399" stroke-width="2" d="M 130,20 130,70" />'
#
# <path stroke="#663399" stroke-width="2" d="M 130,70 30,70" />'
#
# <path stroke="#663399" stroke-width="2" d="M 30,70 30,20" />'
#
# <path stroke="#663399" stroke-width="2" d="M 30,20 190,20" />'
#
# <path stroke="#663399" stroke-width="2" d="M 190,20 190,110" />'
#
# <path stroke="#663399" stroke-width="2" d="M 190,110 30,110" />'
#
# <path stroke="#663399" stroke-width="2" d="M 30,110 30,20" />'
#
# <g transform="rotate(-90.0,30,20) translate(30, 20)">
#     <circle stroke="#63A375" stroke-width="2" fill="transparent" r="5.5" cx="0" cy="0"/>
#     <polygon points="0,12 2,9 -2,9" style="fill:#63A375;stroke:#63A375;stroke-width:2"/>
# </g>
#
# </svg>

# %%
# %%add_method_to Rectangle_1
#
# def translate(self, dx, dy):
#     self.corner.translate(dx, dy)

# %%
box2.translate(30, 20)
print(box2)
# Out:
# Rectange(160, 90, Point(60, 40))

# %%
make_turtle()
line1.draw()
line2.draw()
box1.draw()
box2.draw()
# Out:
# <svg width="300" height="150" style="fill:none; stroke-linecap:round;">
#     <rect width="100%" height="100%" fill="#F3F3F7" />
#
#
# <path stroke="#663399" stroke-width="2" d="M 150,75" />'
#
# <path stroke="#663399" stroke-width="2" d="M 0,0 300,0" />'
#
# <path stroke="#663399" stroke-width="2" d="M 0,0 0,150" />'
#
# <path stroke="#663399" stroke-width="2" d="M 60,40 160,40" />'
#
# <path stroke="#663399" stroke-width="2" d="M 160,40 160,90" />'
#
# <path stroke="#663399" stroke-width="2" d="M 160,90 60,90" />'
#
# <path stroke="#663399" stroke-width="2" d="M 60,90 60,40" />'
#
# <path stroke="#663399" stroke-width="2" d="M 60,40 220,40" />'
#
# <path stroke="#663399" stroke-width="2" d="M 220,40 220,130" />'
#
# <path stroke="#663399" stroke-width="2" d="M 220,130 60,130" />'
#
# <path stroke="#663399" stroke-width="2" d="M 60,130 60,40" />'
#
# <g transform="rotate(-90.0,60,40) translate(60, 40)">
#     <circle stroke="#63A375" stroke-width="2" fill="transparent" r="5.5" cx="0" cy="0"/>
#     <polygon points="0,12 2,9 -2,9" style="fill:#63A375;stroke:#63A375;stroke-width:2"/>
# </g>
#
# </svg>

# %%
box1 is box2
# Out:
# False

# %%
box1.corner is box2.corner
# Out:
# True

# %%
corner = Point(20, 20)
box3 = Rectangle_1(150, 200, corner)
print(box3)
# Out:
# Rectangle(150, 200, Point(20, 20))

# %%
box4 = deepcopy(box3)

# %%
box3 is box4
# Out:
# False

# %%
box3.corner is box4.corner
# Out:
# False

# %%
box3.translate(50,30)
box4.grow(100,60)

# %%
make_turtle()
line1.draw()
line2.draw()
box3.draw()
box4.draw()
# Out:
# <svg width="300" height="150" style="fill:none; stroke-linecap:round;">
#     <rect width="100%" height="100%" fill="#F3F3F7" />
#
#
# <path stroke="#663399" stroke-width="2" d="M 150,75" />'
#
# <path stroke="#663399" stroke-width="2" d="M 0,0 300,0" />'
#
# <path stroke="#663399" stroke-width="2" d="M 0,0 0,150" />'
#
# <path stroke="#663399" stroke-width="2" d="M 70,50 220,50" />'
#
# <path stroke="#663399" stroke-width="2" d="M 220,50 220,250" />'
#
# <path stroke="#663399" stroke-width="2" d="M 220,250 70,250" />'
#
# <path stroke="#663399" stroke-width="2" d="M 70,250 70,50" />'
#
# <path stroke="#663399" stroke-width="2" d="M 20,20 270,20" />'
#
# <path stroke="#663399" stroke-width="2" d="M 270,20 270,280" />'
#
# <path stroke="#663399" stroke-width="2" d="M 270,280 20,280" />'
#
# <path stroke="#663399" stroke-width="2" d="M 20,280 20,20" />'
#
# <g transform="rotate(-90.0,20,20) translate(20, 20)">
#     <circle stroke="#63A375" stroke-width="2" fill="transparent" r="5.5" cx="0" cy="0"/>
#     <polygon points="0,12 2,9 -2,9" style="fill:#63A375;stroke:#63A375;stroke-width:2"/>
# </g>
#
# </svg>

# %%
shapes = [line1, line2, box3, box4]
make_turtle()
for shape in shapes:
    shape.draw()
# Out:
# <svg width="300" height="150" style="fill:none; stroke-linecap:round;">
#     <rect width="100%" height="100%" fill="#F3F3F7" />
#
#
# <path stroke="#663399" stroke-width="2" d="M 150,75" />'
#
# <path stroke="#663399" stroke-width="2" d="M 0,0 300,0" />'
#
# <path stroke="#663399" stroke-width="2" d="M 0,0 0,150" />'
#
# <path stroke="#663399" stroke-width="2" d="M 70,50 220,50" />'
#
# <path stroke="#663399" stroke-width="2" d="M 220,50 220,250" />'
#
# <path stroke="#663399" stroke-width="2" d="M 220,250 70,250" />'
#
# <path stroke="#663399" stroke-width="2" d="M 70,250 70,50" />'
#
# <path stroke="#663399" stroke-width="2" d="M 20,20 270,20" />'
#
# <path stroke="#663399" stroke-width="2" d="M 270,20 270,280" />'
#
# <path stroke="#663399" stroke-width="2" d="M 270,280 20,280" />'
#
# <path stroke="#663399" stroke-width="2" d="M 20,280 20,20" />'
#
# <g transform="rotate(-90.0,20,20) translate(20, 20)">
#     <circle stroke="#63A375" stroke-width="2" fill="transparent" r="5.5" cx="0" cy="0"/>
#     <polygon points="0,12 2,9 -2,9" style="fill:#63A375;stroke:#63A375;stroke-width:2"/>
# </g>
#
# </svg>

# %%
# Exercises

# %%
#Q.1
p1 = Point(30, 20)
p2 = Point(30, 20)
line3 = Line(p1, p2)
line4 = Line(p1, p2)

# %%
line3 is line4
# Out:
# False

# %%
line3 == line4
# Out:
# False

# %%
# %%add_method_to Line
#
# def __eq__(self, other):
#     return (self.p1 == other.p1) and (self.p2 == other.p2)

# %%
line3 == line4
# Out:
# True

# %%
line3 is line4
# Out:
# False

# %%
# Q.2

# %%
# %%add_method_to Line
#
# def midpoint(self):
#     x = (self.p1.x + self.p2.x) / 2
#     y = (self.p1.y + self.p2.y) / 2
#     return Point(x,y)

# %%
mp_line2 = Line.midpoint(line2)

# %%
print(mp_line2)
# Out:
# Point(0.0, 75.0)

# %%
print(box1)
# Out:
# Rectange(100, 50, Point(60, 40))

# %%
# Q.3

# %%
# %%add_method_to Rectangle
#
# def midpoint(self):
#     Mx = (self.width)/2
#     My = (self.heigth)/2
#     return Point(Mx, My)

# %%
mb = box1.midpoint()

# %%
print(mb)
# Out:
# Point(50.0, 25.0)

# %%
# Q.4

# %%
# %%add_method_to Rectangle
#
# def make_cross(self):
#     sides = self.make_lines()
#
#     midpoints = [side.midpoint() for side in sides]
#
#     cross_line1 = Line(midpoints[0], midpoints[2])
#     cross_line2 = Line(midpoints[1], midpoints[3])
#
#     return [cross_line1, cross_line2]

# %%
box = box1.make_cross()

# %%
for l in box:
    print(l)
# Out:
# Line(Point(110.0, 40.0), Point(110.0, 90.0))
# Line(Point(160.0, 65.0), Point(60.0, 65.0))

# %%
# Q.5

# %%
from jupyturtle import penup, pendown, forward, right
import math

# %%
class Circle:
    """Represents a circle.
    
    attributes: center, radius
    """
    def __init__(self, center, radius):
        self.center = center 
        self.radius = radius

    def __str__(self):
        return f'Circle({self.center}, {self.radius})'
    
    def draw(self):

        steps = 120
        circumference = 2 * math.pi * self.radius
        step_length = circumference / steps
        step_angle = 360 / steps

        for _ in range(steps):
            forward(step_length)
            right(step_angle)

# %%
make_turtle()
p = Point(0, 0)
circle = Circle(p, 20)
circle.draw()
# Out:
# <svg width="300" height="150" style="fill:none; stroke-linecap:round;">
#     <rect width="100%" height="100%" fill="#F3F3F7" />
#
#
# <path stroke="#663399" stroke-width="2" d="M 150,75 151,75 152.1,75.1 153.1,75.2 154.2,75.3 155.2,75.5 156.2,75.8 157.2,76.1 158.2,76.5 159.1,76.9 160.1,77.4 161,77.9 161.9,78.5 162.7,79.1 163.5,79.8 164.3,80.5 165,81.2 165.7,82 166.4,82.8 167,83.7 167.6,84.5 168.1,85.5 168.6,86.4 169,87.3 169.4,88.3 169.7,89.3 170,90.3 170.2,91.4 170.4,92.4 170.5,93.4 170.5,94.5 170.5,95.5 170.5,96.6 170.4,97.6 170.2,98.6 170,99.7 169.7,100.7 169.4,101.7 169,102.6 168.6,103.6 168.1,104.5 167.6,105.4 167,106.3 166.4,107.2 165.7,108 165,108.8 164.3,109.5 163.5,110.2 162.7,110.9 161.9,111.5 161,112.1 160.1,112.6 159.1,113 158.2,113.5 157.2,113.9 156.2,114.2 155.2,114.4 154.2,114.7 153.1,114.8 152.1,114.9 151,115 150,115 149,114.9 147.9,114.8 146.9,114.7 145.9,114.4 144.8,114.2 143.8,113.9 142.9,113.5 141.9,113 141,112.6 140.1,112.1 139.2,111.5 138.3,110.9 137.5,110.2 136.8,109.5 136,108.8 135.3,108 134.7,107.2 134,106.3 133.5,105.4 132.9,104.5 132.5,103.6 132,102.6 131.7,101.7 131.3,100.7 131.1,99.7 130.9,98.6 130.7,97.6 130.6,96.6 130.5,95.5 130.5,94.5 130.6,93.4 130.7,92.4 130.9,91.4 131.1,90.3 131.3,89.3 131.7,88.3 132,87.3 132.5,86.4 132.9,85.5 133.5,84.5 134,83.7 134.7,82.8 135.3,82 136,81.2 136.8,80.5 137.5,79.8 138.3,79.1 139.2,78.5 140.1,77.9 141,77.4 141.9,76.9 142.9,76.5 143.8,76.1 144.8,75.8 145.9,75.5 146.9,75.3 147.9,75.2 149,75.1 150,75" />'
#
# <g transform="rotate(-90.0,150.0,75.0) translate(150.0, 75.0)">
#     <circle stroke="#63A375" stroke-width="2" fill="transparent" r="5.5" cx="0" cy="0"/>
#     <polygon points="0,12 2,9 -2,9" style="fill:#63A375;stroke:#63A375;stroke-width:2"/>
# </g>
#
# </svg>
