# %%
name = 'John Snow'

# %%
def actor(): # function definition
    print(name)
    print('Elizabeth')

# %%
actor()
# Out:
# John Snow
# Elizabeth

# %%
actor
# Out:
# <function __main__.actor()>

# %%
def actor_name(name):# varaible name inside the parenthesis is called parameter
    print(name)

actor_name("Chris Hemsworth") # calling function with arguments
# Out:
# Chris Hemsworth

# %%
'''Writing this 
"Hello, Hello, Hello, Hello,
Mic Testing, Mic Testing,
My self Raj and i am learning function."
'''
# Out:
# 'Writing this \n"Hello, Hello, Hello, Hello,\nMic Testing, Mic Testing,\nMy self Raj and i am learning function."\n'

# %%
def first_line(greet,n):# giving two parameters.
    print(greet * n)

# %%
def second_line(test, n):
    print(test * n)

# %%
def third_line(message):
    print(message)

# %%
def complete_message():#  Calling multiple function in a function.
    first_line("Hello, ", 4)# Giving two positional arguments.
    second_line("Mic Testing, ",2)
    third_line("My self Raj and i am learning function.")

# %%
complete_message()
# Out:
# Hello, Hello, Hello, Hello,
# Mic Testing, Mic Testing,
# My self Raj and i am learning function.

# %%
for i in range(5):# printing number 0 to 4
    print (i)
# Out:
# 0
# 1
# 2
# 3
# 4

# %%
def print_n_verse(n):# Function definitons
    for i in range(n):# for loop for printing verse n no. of times
        print("Message",i)
        complete_message()
        print("\n")

# %%
print_n_verse(2)# calling function with argument 2
# Out:
# Message 0
# Hello, Hello, Hello, Hello,
# Mic Testing, Mic Testing,
# My self Raj and i am learning function.
#
#
# Message 1
# Hello, Hello, Hello, Hello,
# Mic Testing, Mic Testing,
# My self Raj and i am learning function.

# %%
message_1 = "Coding is Amazing," # point two string with two different variables
message_2 = "For Coders."

# %%
def combine(m1,m2): # providing two parameters to the function
    message = m1 + m2 # string concatenation
    print(message)

# %%
# variables inside a function and parameters are local 
# print(message)
# print(m1,m2)

# %%
# giving function as a parameter to the function 
def greet_1(name):
    print("Hello",name)

def call_function(func,value):
    print(func(value))

# %%
call_function(greet_1,"Raj")
# Out:
# Hello Raj
# None

# %%
"""Write a function named print_right that takes a string named text as a parameter
and prints the string with enough leading spaces that the last letter of the string is in
the 40th column of the display.
Hint: use the len function, the string concatenation operator (+), and the string repe
tition operator (*).
Here’s an example that shows how it should work:
print_right("Monty")
print_right("Python's")
print_right("Flying Circus")
                                Monty
                             Python's
                        Flying Circus"""
# Out:
# 'Write a function named print_right that takes a string named text as a parameter\nand prints the string with enough leading spaces that the last letter of the string is in\nthe 40th column of the display.\nHint: use the len function, the string concatenation operator (+), and the string repe\ntition operator (*).\nHere’s an example that shows how it should work:\nprint_right("Monty")\nprint_right("Python\'s")\nprint_right("Flying Circus")\n                                Monty\n                             Python\'s\n                        Flying Circus'

# %%
def print_right(text):
    """Printing string to the 40th column"""
    space = " " * (40-len(text)) # we use len to count the string
    print(space + text) # string concatenation

# %%
print_right("Monty")
print_right("Python's")
print_right("Flying Circus")
# Out:
#                                    Monty
#                                 Python's
#                            Flying Circus

# %%
"""Write a function called triangle that takes a string and an integer and
draws a triangle with the given height, made up of copies of the string.
Here’s an example of a triangle with five levels using the string 'L':
triangle('L', 5)
L
LL
LLL
LLLL
LLLLL"""
# Out:
# "Write a function called triangle that takes a string and an integer and\ndraws a triangle with the given height, made up of copies of the string.\nHere’s an example of a triangle with five levels using the string 'L':\ntriangle('L', 5)\nL\nLL\nLLL\nLLLL\nLLLLL"

# %%
def triangle(pattern, n):
    """Function to display triangle pattern."""
    for i in range(n+1):
        print(pattern * i, end="\n") # used end funtion to to use as a newline

# %%
triangle('L',5)
# Out:
# L
# LL
# LLL
# LLLL
# LLLLL

# %%
"""Write a function called rectangle that takes a string and two integers and draws a
rectangle with the given width and height, made up of copies of the string. Here’s an
example of a rectangle with width 5 and height 4, using the string 'H':
rectangle('H', 5, 4)
HHHHH
HHHHH
HHHHH
HHHHH"""
# Out:
# "Write a function called rectangle that takes a string and two integers and draws a\nrectangle with the given width and height, made up of copies of the string. Here’s an\nexample of a rectangle with width 5 and height 4, using the string 'H':\nrectangle('H', 5, 4)\nHHHHH\nHHHHH\nHHHHH\nHHHHH"

# %%
def rectangle(pattern, w, h):
    """Displaying rectangle pattern with two parameters."""
    for j in range(h):
        print(pattern * w)

# %%
rectangle("H", 5, 6)
# Out:
# HHHHH
# HHHHH
# HHHHH
# HHHHH
# HHHHH
# HHHHH

# %%
"""Exercise
The song “99 Bottles of Beer” starts with this verse:

99 bottles of beer on the wall,
99 bottles of beer.
Take one down, pass it around,
98 bottles of beer on the wall.

Then the second verse is the same, except that it starts with 98 bottles and ends with 97.
The song continues—for a very long time—until there are 0 bottles of beer.
Write a function called bottle_verse that takes a number as a parameter 
and displays the verse that starts with the given number of bottles.

Hint: consider starting with a function that can print the first, second, or
last line of the verse, and then use it to write bottle_verse."""
# Out:
# 'Exercise\nThe song “99 Bottles of Beer” starts with this verse:\n\n99 bottles of beer on the wall,\n99 bottles of beer.\nTake one down, pass it around,\n98 bottles of beer on the wall.\n\nThen the second verse is the same, except that it starts with 98 bottles and ends with 97.\nThe song continues—for a very long time—until there are 0 bottles of beer.\nWrite a function called bottle_verse that takes a number as a parameter \nand displays the verse that starts with the given number of bottles.\n\nHint: consider starting with a function that can print the first, second, or\nlast line of the verse, and then use it to write bottle_verse.'

# %%
def line_1(x):
    """First two lines of the verse"""
    print(x," bottles of beer on the wall,")
    print(x," bottles of beer.")

def line_2():
    """Third line of the verse"""
    print("Take one down, pass it around,")

def bottle_verse(x):
    """Whole verse"""
    line_1(x)
    line_2()
    print(x-1," bottles of beer on the wall.")

# %%
# Printing the verse untill 0 bottle
for n in range(99, 0, -1):
    bottle_verse(n)
    print()
# Out:
# 99  bottles of beer on the wall,
# 99  bottles of beer.
# Take one down, pass it around,
# 98  bottles of beer on the wall.
#
# 98  bottles of beer on the wall,
# 98  bottles of beer.
# Take one down, pass it around,
# 97  bottles of beer on the wall.
#
# 97  bottles of beer on the wall,
# 97  bottles of beer.
# Take one down, pass it around,
# 96  bottles of beer on the wall.
#
# 96  bottles of beer on the wall,
# 96  bottles of beer.
# Take one down, pass it around,
# 95  bottles of beer on the wall.
#
# 95  bottles of beer on the wall,
# 95  bottles of beer.
# Take one down, pass it around,
# 94  bottles of beer on the wall.
#
# 94  bottles of beer on the wall,
# 94  bottles of beer.
# Take one down, pass it around,
# 93  bottles of beer on the wall.
#
# 93  bottles of beer on the wall,
# 93  bottles of beer.
# Take one down, pass it around,
# 92  bottles of beer on the wall.
#
# 92  bottles of beer on the wall,
# 92  bottles of beer.
# Take one down, pass it around,
# ...
