# %%
import math
def circle_area(radius):
    area = 2 * math.pi * radius 
    return area

# %%
circle_area(45)
# Out:
# 282.7433388230814

# %%
def repeat(string, n):
    result = string * n
    print(result)

# %%
repeat("hello ", 3)
# Out:
# hello hello hello

# %%
result =  repeat("hello ",3)
# Out:
# hello hello hello

# %%
result # it return None becuae functon in result variable doesn't have a
# return value.

# %%
def repeat_string(string, n):
    """Now with return value."""
    return string * n

# %%
repeat_string("Hello ",3)
# Out:
# 'Hello Hello Hello '

# %%
line = repeat_string("Hello ", 3 )

# %%
line
# Out:
# 'Hello Hello Hello '

# %%
# we can right abs() like this also 
def absolute_value(x):
    if x<0:
        return -x
    else:
        return x

# %%
absolute_value(-234)
# Out:
# 234

# %%
# modified version of the abs function with aditional return value
def absolute(x):
    if x < 0:
        return -x
    else: 
        return x
    return 'This is dead code'
# the code that can never run is called dead code

# %%
def distance(x1 ,y1 ,x2 ,y2 ):
    X = x2 - x1
    Y = y2 - y1
    dsquare = X**2 + Y**2
    result = math.sqrt(dsquare)
    return result

# %%
distance(1,2,4,6)
# Out:
# 5.0

# %%
def is_divisible(x, y):
    return x % y == 0

# %%
if is_divisible(6,3):
    print("Divisible")
# Out:
# Divisible

# %%
def factorial(n):
    return 0

# %%
def factorial(n):
    if n == 0:
        return 1
    else: 
        return 0

# %%
def factorial(n):
    """factorial of number"""
    if n == 0:
        return 1
    elif n > 0:
        recurse = factorial(n-1)
        return n * recurse

# %%
factorial(5)
# Out:
# 120

# %%
"""Fibonacci series 0 1 1 2 3 5 8 13 21
f(0) = 0
f(1) = 1
f(n) = f(n-1) + f(n-2)"""
# Out:
# 'Fibonacci series 0 1 1 2 3 5 8 13 21\nf(0) = 0\nf(1) = 1\nf(n) = f(n-1) + f(n-2)'

# %%
def fibonacci(n):
    if n == 0:
        return 0
    elif n == 1:
        return 1
    else:
        return fibonacci(n-1) + fibonacci(n-2)

# %%
fibonacci(6)
# Out:
# 8

# %%
def factorial(n):
    if not isinstance(n, int):
        print("factorial is only defined for integers.")
        return None
    elif n < 0:
        print("factorial is not defined for negative numbers.")
        return None
    elif n == 0:
        return 1
    else:
        return n * factorial(n-1)

# %%
factorial(4)
# Out:
# 24

# %%
"""Use incremental development to write a function called hypot that returns the length
of the hypotenuse of a right triangle given the lengths of the other two legs as
arguments. 
Note that there’s a function in the math module called hypot that does the same thing,
but you should not use it for this exercise!
Even if you can write the function correctly on the first try, start with a function that
always returns 0 and practice making small changes, testing as you go. When you are
done, the function should only return a value—it should not display anything."""
# Out:
# 'Use incremental development to write a function called hypot that returns the length\nof the hypotenuse of a right triangle given the lengths of the other two legs as\narguments. \nNote that there’s a function in the math module called hypot that does the same thing,\nbut you should not use it for this exercise!\nEven if you can write the function correctly on the first try, start with a function that\nalways returns 0 and practice making small changes, testing as you go. When you are\ndone, the function should only return a value—it should not display anything.'

# %%
def hypot(l1, l2):
    sl1 = l1**2
    sl2 = l2**2
    return math.sqrt(sl1 + sl2)

# %%
hypot(3,4)
# Out:
# 5.0

# %%
"""Write a boolean function, is_between(x, y, z), that returns True if x < y < z or if
z < y <x, and False otherwise."""
# Out:
# 'Write a boolean function, is_between(x, y, z), that returns True if x < y < z or if\nz < y <x, and False otherwise.'

# %%
def is_between(x, y, z):
    if x<y<z or z<y<x:
        return True
    else:
        return False

# %%
"""The Ackermann function
Write a function named ackermann that evaluates the Ackermann function. What
happens if you call ackermann(5, 5)?"""
# Out:
# 'The Ackermann function, \nn +1\nAm,n =\nAm,n\n, is  defined as:\nif m = 0\nAm−1,1 if m>0andn=0\nAm−1,Am,n−1 if m>0 and n>0.\nWrite a function named ackermann that evaluates the Ackermann function. What\nhappens if you call ackermann(5, 5)?'

# %%
def ackermann(m, n):
    if m == 0:
        return n + 1
    if m > 0 and n == 0:
        return ackermann(m-1,1)
    return ackermann(m-1,ackermann(m, n-1))

# %%
ackermann(5,5)
# Out:
# ---------------------------------------------------------------------------
# RecursionError                            Traceback (most recent call last)
# Cell In[96], line 1
# ----> 1 ackermann(5,5)
#
# Cell In[90], line 6, in ackermann(m, n)
#       4 if m > 0 and n == 0:
#       5     return ackermann(m-1,1)
# ----> 6 return ackermann(m-1,ackermann(m, n-1))
#
# Cell In[90], line 6, in ackermann(m, n)
#       4 if m > 0 and n == 0:
#       5     return ackermann(m-1,1)
# ----> 6 return ackermann(m-1,ackermann(m, n-1))
#
#     [... skipping similar frames: ackermann at line 6 (2 times)]
#
# Cell In[90], line 6, in ackermann(m, n)
#       4 if m > 0 and n == 0:
#       5     return ackermann(m-1,1)
# ----> 6 return ackermann(m-1,ackermann(m, n-1))
#
# Cell In[90], line 5, in ackermann(m, n)
#       3     return n + 1
#       4 if m > 0 and n == 0:
# ----> 5     return ackermann(m-1,1)
#       6 return ackermann(m-1,ackermann(m, n-1))
#
# Cell In[90], line 6, in ackermann(m, n)
# ...

# %%
def gcd(a, b):
    if b == 0:
        return a
    return gcd(b,a%b)

gcd(48, 18)
# Out:
# 6

# %%
gcd(100,25)
# Out:
# 25
